# %% [raw]
# # import the library

# %%
import pandas as pd
import numpy as np
import sklearn as sn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load the dataset
s1=pd.read_csv("health care diabetes.csv")

# %%
#check the shape of tthe dataset
s1.shape
# Out:
# (768, 9)

# %%
s1.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#check the first 7 rows from the dataset
s1.head(6)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0

# %%
#check for last 5 rows in dataset
s1.tail(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
s1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#describe shows five point summary
s1.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
s1.isna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
#check null 
s1.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
print("Standard deviation of each variable are present")
s1.apply(np.std)
# Out:
# Standard deviation of each variable are present
# Pregnancies                   3.367384
# Glucose                      31.951796
# BloodPressure                19.343202
# SkinThickness                15.941829
# Insulin                     115.168949
# BMI                           7.879026
# DiabetesPedigreeFunction      0.331113
# Age                          11.752573
# Outcome                       0.476641
# dtype: float64

# %%
s1.skew(axis = 0, skipna = True).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Treating Missing Values and Analysing Distribution of Data-set**

# %%
print(len(s1.columns))
# Out:
# 9

# %%
s1.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
s1.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
s1.dtypes.value_counts()
# Out:
# int64      7
# float64    2
# dtype: int64

# %%
# how many 0 value are present inside Glucose column.
count =(s1['Glucose']==0).sum()
count
# Out:
# 5

# %%
#Glucose before converting 0 to mean
plt.hist(s1['Glucose'])
print("Mean of Glucose level is :-", s1['Glucose'].mean())
print("Datatype of Glucose Variable is:",s1['Glucose'].dtypes)
# Out:
# Mean of Glucose level is :- 120.89453125
# Datatype of Glucose Variable is: int64

# %%
s1['Glucose'].replace(to_replace = 0, value = s1['Glucose'].mean(), inplace=True)

# %%
count =(s1['Glucose']==0).sum()
count
# Out:
# 0

# %%
# #After converting 0 values to mean for the Glucose & plot its histogram.
plt.figure(figsize=(6,4))
plt.xlabel('Glucose Class')
s1['Glucose'].plot.hist()
sns.set_style(style='darkgrid')
print("Mean of Glucose level is :-", s1['Glucose'].mean())
print("Datatype of Glucose Variable is:",s1['Glucose'].dtypes)
# Out:
# Mean of Glucose level is :- 121.68160502115886
# Datatype of Glucose Variable is: float64

# %%
# how many 0 value are present inside BloodPressure column.
BloodPressure_before_count =(s1['BloodPressure']==0).sum()
BloodPressure_before_count
# Out:
# 35

# %%
#BloodPressure before converting 0 to mean
plt.hist(s1['BloodPressure'])
print("Mean of BloodPressure level is :-", s1['BloodPressure'].mean())
print("Datatype of BloodPressure Variable is:",s1['BloodPressure'].dtypes)
# Out:
# Mean of BloodPressure level is :- 69.10546875
# Datatype of BloodPressure Variable is: int64

# %%
s1['BloodPressure'].replace(to_replace = 0, value = s1['BloodPressure'].mean(), inplace=True)

# %%
BloodPressure_before_count =(s1['BloodPressure']==0).sum()
BloodPressure_before_count
# Out:
# 0

# %%
#BloodPressure after converting 0 to mean
plt.hist(s1['BloodPressure'])
print("Mean of BloodPressure level is :-", s1['BloodPressure'].mean())
print("Datatype of BloodPressure Variable is:",s1['BloodPressure'].dtypes)
# Out:
# Mean of BloodPressure level is :- 72.25480651855469
# Datatype of BloodPressure Variable is: float64

# %%
# how many 0 value are present inside BMI column.
count =(s1['BMI']==0).sum()
count
# Out:
# 11

# %%
#BMI Before converting 0 to mean
plt.hist(s1['BMI'])
print("Mean of BMI level is :-", s1['BMI'].mean())
print("Datatype of BMI Variable is:",s1['BMI'].dtypes)
# Out:
# Mean of BMI level is :- 31.992578124999977
# Datatype of BMI Variable is: float64

# %%
s1['BMI'].replace(to_replace = 0, value = s1['BMI'].mean(), inplace=True)

# %%
count =(s1['BMI']==0).sum()
count
# Out:
# 0

# %%
##After converting 0 values to mean for the BMI & plot its histogram.
plt.figure(figsize=(6,4))
plt.xlabel('BMI Class')
s1['BMI'].plot.hist()
sns.set_style(style='darkgrid')
print("Mean of BMI is :-", s1['BMI'].mean())
print("Datatype of BMI Variable is:",s1['BMI'].dtypes)
# Out:
# Mean of BMI is :- 32.45080515543617
# Datatype of BMI Variable is: float64

# %%
#How many 0 columns are present in Insulin we have to check.
count =(s1['Insulin']==0).sum()
count
# Out:
# 374

# %%
#Insulin before converting 0 to mean
plt.hist(s1['Insulin'])
print("Mean of Insulin level is :-", s1['Insulin'].mean())
print("Datatype of Insulin Variable is:",s1['Insulin'].dtypes)
# Out:
# Mean of Insulin level is :- 79.79947916666667
# Datatype of Insulin Variable is: int64

# %%
s1["Insulin"].replace(to_replace=0, value=s1["Insulin"].mean(),inplace=True)

# %%
Count=(s1["Insulin"]==0).sum()
Count
# Out:
# 0

# %%
#After converting 0 to mean
plt.figure(figsize=(6,4))
plt.xlabel("insulin")
plt.hist(s1["Insulin"])
plt.show()

# %%
#How many 0 columns are present  In SkinThickness we have to check.
SkinThickness_before_count =(s1['SkinThickness']==0).sum()
SkinThickness_before_count
# Out:
# 227

# %%
#SkinThickness before converting 0 to mean
plt.hist(s1['SkinThickness'])
print("Mean of SkinThickness level is :-", s1['SkinThickness'].mean())
print("Datatype of SkinThickness Variable is:",s1['SkinThickness'].dtypes)
# Out:
# Mean of SkinThickness level is :- 20.536458333333332
# Datatype of SkinThickness Variable is: int64

# %%
s1["SkinThickness"].replace(to_replace=0, value=s1["SkinThickness"].mean(),inplace=True)

# %%
Count=(s1["SkinThickness"]==0).sum()
Count
# Out:
# 0

# %%
#SkinThickness After converting 0 to mean
#plt.hist(s1['SkinThickness'])
plt.figure(figsize=(6,4))
plt.xlabel("Skinthickness")
s1["SkinThickness"].plot.hist()
plt.show()
print("Mean of Insulin level is :-", s1['Insulin'].mean())
print("Datatype of Insulin Variable is:",s1['Insulin'].dtypes)
# Out:
# Mean of Insulin level is :- 118.66016303168442
# Datatype of Insulin Variable is: float64

# %%
#value counts for BMI
s1['BMI'].value_counts().head(8)
# Out:
# 32.000000    13
# 31.600000    12
# 31.200000    12
# 31.992578    11
# 32.400000    10
# 33.300000    10
# 30.100000     9
# 32.800000     9
# Name: BMI, dtype: int64

# %%
#value count  for  Glucose
s1['Glucose'].value_counts().head(7)
# Out:
# 99.0     17
# 100.0    17
# 111.0    14
# 129.0    14
# 125.0    14
# 106.0    14
# 112.0    13
# Name: Glucose, dtype: int64

# %%
#value counts for SkinThickness
s1['SkinThickness'].value_counts().head(7)
# Out:
# 20.536458    227
# 32.000000     31
# 30.000000     27
# 27.000000     23
# 23.000000     22
# 33.000000     20
# 28.000000     20
# Name: SkinThickness, dtype: int64

# %%
#value counts for BloodPressure
s1['BloodPressure'].value_counts().head(7)
# Out:
# 70.0    57
# 74.0    52
# 78.0    45
# 68.0    45
# 72.0    44
# 64.0    43
# 80.0    40
# Name: BloodPressure, dtype: int64

# %%
#value counts for Insulin
s1['Insulin'].value_counts().head(7)
# Out:
# 79.799479     374
# 105.000000     11
# 130.000000      9
# 140.000000      9
# 120.000000      8
# 94.000000       7
# 180.000000      7
# Name: Insulin, dtype: int64

# %% [markdown]
# **Checking Missing value with heatMap**

# %% [markdown]
# **Exploratory Data Analysis**

# %%
#checking Missing value with heatmap
import seaborn as sns
plt.figure(figsize=(5,3),dpi=100)
plt.title('Checking Missing Value with Heatmap')
sns.heatmap(s1.isnull(),cmap='magma',yticklabels=False)
# Out:
# <AxesSubplot:title={'center':'Checking Missing Value with Heatmap'}>

# %% [markdown]
# **Count Plot**
#
# Check the balance of the data by plotting the count of outcomes by their value. Describe your findings and plan future course of action.

# %%
#create the count plot
sns.set_style('darkgrid')
sns.countplot(s1['Outcome'])
plt.title("Countplot of Outcome")
plt.xlabel('Outcome')
plt.ylabel("Count")
print("Count of class is:\n",s1['Outcome'].value_counts())
# Out:
# d:\Users\admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Count of class is:
#  0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
print("Count of class is:\n",s1['Outcome'].value_counts())
# Out:
# Count of class is:
#  0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [raw]
# # Since classes in Outcome is little skewed so we will generate new samples using SMOTE(Synthetic Minority Oversampling Technique) for the class '1' which is under-represented in our data. We will use SMOTE out of many other techniques available since:
# It generates new samples by interpolation.
# It doesn't duplicate data.

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.datasets import make_classification

# %%
s1_X = s1.drop('Outcome', axis=1)
s1_y = s1['Outcome']
print(s1_X.shape, s1_y.shape)
# Out:
# (768, 8) (768,)

# %%
s1_X_resampled, s1_y_resampled = SMOTE(random_state=108).fit_resample(s1_X, s1_y)
print(s1_X_resampled.shape, s1_y_resampled.shape)
#print('Original dataset shape %s' % Counter(y))
# Out:
# (1000, 8) (1000,)

# %%
s1_y_resampled.value_counts().plot(kind='bar')
s1_y_resampled.value_counts()
# Out:
# 1    500
# 0    500
# Name: Outcome, dtype: int64

# %% [markdown]
# ## Scatter Plot
#
# #Create scatter charts between the pair of variables to understand the relationships. Describe your findings.

# %%
sns.pairplot(s1)
plt.title("Scatter plot between  all variables")
# Out:
# Text(0.5, 1.0, 'Scatter plot between  all variables')

# %%
#scatter plot between glucose and insulin

# %%
plt.scatter(s1["Insulin"], s1["Glucose"] )
plt.xlabel("Insulin") #x label
plt.ylabel("Glucose") #y label
plt.show()

# %%
#creating a scatter plot
plt.scatter(s1['BMI'], s1['Insulin'])
plt.xlabel("BMI") #x label
plt.ylabel("Insulin") #y label
plt.show()

# %%
plt.scatter(s1['BloodPressure'], s1['Glucose'])
plt.xlabel("BloodPressure") #x label
plt.ylabel("Glucose") #y label
plt.show()

# %% [markdown]
# #**Correlation Analysis**

# %%
s1.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.127964       0.208984       0.013376
# Glucose                      0.127964  1.000000       0.219666       0.160766
# BloodPressure                0.208984  0.219666       1.000000       0.134155
# SkinThickness                0.013376  0.160766       0.134155       1.000000
# Insulin                     -0.018082  0.396597       0.010926       0.240361
# BMI                          0.021546  0.231478       0.281231       0.535703
# DiabetesPedigreeFunction    -0.033523  0.137106       0.000371       0.154961
# Age                          0.544341  0.266600       0.326740       0.026423
# Outcome                      0.221898  0.492908       0.162986       0.175026
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.021546                 -0.033523
# Glucose                   0.396597  0.231478                  0.137106
# BloodPressure             0.010926  0.281231                  0.000371
# SkinThickness             0.240361  0.535703                  0.154961
# Insulin                   1.000000  0.189856                  0.157806
# BMI                       0.189856  1.000000                  0.153508
# DiabetesPedigreeFunction  0.157806  0.153508                  1.000000
# Age                       0.038652  0.025748                  0.033561
# Outcome                   0.179185  0.312254                  0.173844
#
#                                Age   Outcome
# Pregnancies               0.544341  0.221898
# Glucose                   0.266600  0.492908
# BloodPressure             0.326740  0.162986
# SkinThickness             0.026423  0.175026
# Insulin                   0.038652  0.179185
# BMI                       0.025748  0.312254
# DiabetesPedigreeFunction  0.033561  0.173844
# Age                       1.000000  0.238356
# Outcome                   0.238356  1.000000

# %%
sns.heatmap(s1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(dpi=80)
sns.heatmap(s1.corr(),cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Modelling

# %% [markdown]
# Data Preprocessing

# %%
#loc is label-based, which means that you have to specify rows and 
#columns based on their row and column labels.
X=s1.iloc[:,:-1].values
y=s1.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
#now we have import train test split from sklearn.model_selection
#now split our dataset into 80% training and 20% testing & 
#random state is treated as hyperparameter which control the shuffing process.
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=0)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %% [markdown]
# ### KNN

# %%
#first we have to import metrics
from sklearn import metrics

# %%
#Now time to import KNeighborsClassifier and Predict
from sklearn.neighbors import KNeighborsClassifier
knn_model_value = KNeighborsClassifier(n_neighbors=45) 
knn_model_value.fit(X_train,y_train)
knn_pred_norm=knn_model_value.predict(X_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of KNN Model with Normalization::")
print(metrics.accuracy_score(y_test,knn_pred_norm))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,knn_pred_norm),'\n')
print("\n","ROC Curve")
knn_prob_norm=knn_model_value.predict_proba(X_test)
knn_prob_norm1=knn_prob_norm[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,knn_prob_norm1)
roc_auc_knn=metrics.auc(fpr,tpr)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_knn)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of KNN Model with Normalization::
# 0.8051948051948052
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86       107
#            1       0.72      0.60      0.65        47
#
#     accuracy                           0.81       154
#    macro avg       0.78      0.75      0.76       154
# weighted avg       0.80      0.81      0.80       154
#
#
#
#  ROC Curve
# C:\Users\admin\AppData\Local\Temp/ipykernel_11696/3087014801.py:15: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %% [markdown]
# ### Logistic Regression

# %%
#import Logistic Regression and tried to building a model.
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
lr_model_classifier = LogisticRegression(C=0.01) 
lr_model_classifier.fit(X_train,y_train)
lr_pred=lr_model_classifier.predict(X_test)
# Out:
# d:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
print("Model Validation ==>\n")
print("Accuracy Score of Logistic Regression Model::")
print(metrics.accuracy_score(y_test,lr_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,lr_pred),'\n')
print("\n","Confusion Matrix::")
cm = confusion_matrix(y_test,lr_pred,labels=None)
print(cm)
print("\n","ROC Curve")
lr_prob=lr_model_classifier.predict_proba(X_test)
lr_prob1=lr_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,lr_prob1)
roc_auc_lr=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_lr)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of Logistic Regression Model::
# 0.7207792207792207
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.79      0.81      0.80       107
#            1       0.55      0.51      0.53        47
#
#     accuracy                           0.72       154
#    macro avg       0.67      0.66      0.66       154
# weighted avg       0.72      0.72      0.72       154
#
#
#
#  Confusion Matrix::
# [[87 20]
#  [23 24]]
#
#  ROC Curve
# C:\Users\admin\AppData\Local\Temp/ipykernel_11696/784532161.py:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfm=RandomForestClassifier(n_estimators=1000,random_state=0)
rfm.fit(X_train,y_train)
rfp=rfm.predict(X_test)

# %%
rf_model_classifier = RandomForestClassifier(n_estimators=1000,random_state=0)
rf_model_classifier.fit(X_train,y_train)
rf_pred_classifier=rf_model_classifier.predict(X_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of Random Forest Classifier Model::")
print(metrics.accuracy_score(y_test,rf_pred_classifier))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,rf_pred_classifier),'\n')
print("\n","Confusion Matrix::")
cm = confusion_matrix(y_test,rf_pred_classifier,labels=None)
print(cm)
print("\n","ROC Curve")
rf_prob=rf_model_classifier.predict_proba(X_test)
rf_prob1=rf_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,rf_prob1)
roc_auc_rf=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_rf)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of Random Forest Classifier Model::
# 0.8246753246753247
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       107
#            1       0.71      0.72      0.72        47
#
#     accuracy                           0.82       154
#    macro avg       0.79      0.80      0.79       154
# weighted avg       0.83      0.82      0.83       154
#
#
#
#  Confusion Matrix::
# [[93 14]
#  [13 34]]
#
#  ROC Curve
# C:\Users\admin\AppData\Local\Temp/ipykernel_11696/1370130142.py:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %% [markdown]
# ## Decision Tress Classifier

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import confusion_matrix
dtc_model_classifier = DecisionTreeClassifier() 
dtc_model_classifier.fit(X_train,y_train)
dtc_pred=dtc_model_classifier.predict(X_test)

# %%
print("Model Validation ==>\n")
print("Accuracy Score of Decision Tree Classfier Model::")
print(metrics.accuracy_score(y_test,dtc_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,dtc_pred),'\n')
print("\n","Confusion Matrix::")
cm = confusion_matrix(y_test,dtc_pred,labels=None)
print(cm)
print("\n","ROC Curve")
lr_prob=dtc_model_classifier.predict_proba(X_test)
lr_prob1=lr_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,lr_prob1)
roc_auc_lr=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_lr)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy Score of Decesion Tree Classfier Model::
# 0.7662337662337663
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83       107
#            1       0.61      0.64      0.62        47
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.73      0.73       154
# weighted avg       0.77      0.77      0.77       154
#
#
#
#  Confusion Matrix::
# [[88 19]
#  [17 30]]
#
#  ROC Curve
# C:\Users\admin\AppData\Local\Temp/ipykernel_2192/1069826307.py:19: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %% [markdown]
# ## SVM MODEL

# %%
#from sklearn import svm
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.metrics import classification_report,confusion_matrix

# %%
# ALL Default hyperparameters
svc_model=SVC(probability=True)
svc_model.fit(X_train,y_train)
y_pred=svc_model.predict(X_test)

# %%
#Percentage of observations used to build the SVC (Support Vectors)
svc_model.support_vectors_.shape[0]/s1.shape[0]*100
# Out:
# 48.95833333333333

# %% [markdown]
# Model Evaluation
# Now, get predictions from the model and print accuracy, and create a confusion matrix and a classification report.

# %%
print("Model Validation ==>\n")
print("Accuracy-Score of SVM Model::")
print(metrics.accuracy_score(y_test,y_pred))
print("\n","Classification Report::")
print(metrics.classification_report(y_test,y_pred),'\n')
print("\n","ROC Curve")
svm_prob=svc_model.predict_proba(X_test)
svm_proba1=svm_prob[:,1]
fpr,tpr,thresh=metrics.roc_curve(y_test,svm_proba1)
roc_auc_lr=metrics.auc(fpr,tpr)
plt.figure(dpi=80)
plt.title("ROC Curve")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.plot(fpr,tpr,'b',label='AUC Score = %0.2f'%roc_auc_lr)
plt.plot(fpr,fpr,'r--',color='red')
plt.legend()
# Out:
# Model Validation ==>
#
# Accuracy-Score of SVM Model::
# 0.7922077922077922
#
#  Classification Report::
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86       107
#            1       0.73      0.51      0.60        47
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.71      0.73       154
# weighted avg       0.78      0.79      0.78       154
#
#
#
#  ROC Curve
# C:\Users\admin\AppData\Local\Temp/ipykernel_2192/3473825543.py:16: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(fpr,fpr,'r--',color='red')

# %% [markdown]
#  * END
